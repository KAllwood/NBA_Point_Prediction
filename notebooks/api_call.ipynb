# %%
from nba_api.stats.endpoints import leaguegamelog

df = leaguegamelog.LeagueGameLog(
    season="2023-24",
    player_or_team_abbreviation="P"   # parameter name may vary slightly
).get_data_frames()[0]

df
# Out:
#       SEASON_ID  PLAYER_ID         PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0         22023     202704      Reggie Jackson  1610612743               DEN
# 1         22023     203932        Aaron Gordon  1610612743               DEN
# 2         22023     203999        Nikola Jokić  1610612743               DEN
# 3         22023    1629008  Michael Porter Jr.  1610612743               DEN
# 4         22023    1629618       Jalen Pickett  1610612743               DEN
# ...         ...        ...                 ...         ...               ...
# 26396     22023    1630581         Josh Giddey  1610612760               OKC
# 26397     22023    1630590   Scotty Pippen Jr.  1610612763               MEM
# 26398     22023    1631298          Jack White  1610612763               MEM
# 26399     22023     203995      Vasilije Micic  1610612766               CHA
# 26400     22023    1630550             JT Thor  1610612766               CHA
#
#                    TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP WL  ...  \
# 0             Denver Nuggets  0022300061  2023-10-24  DEN vs. LAL  W  ...
# 1             Denver Nuggets  0022300061  2023-10-24  DEN vs. LAL  W  ...
# 2             Denver Nuggets  0022300061  2023-10-24  DEN vs. LAL  W  ...
# 3             Denver Nuggets  0022300061  2023-10-24  DEN vs. LAL  W  ...
# 4             Denver Nuggets  0022300061  2023-10-24  DEN vs. LAL  W  ...
# ...                      ...         ...         ...          ... ..  ...
# 26396  Oklahoma City Thunder  0022301196  2024-04-14  OKC vs. DAL  W  ...
# 26397      Memphis Grizzlies  0022301193  2024-04-14  MEM vs. DEN  L  ...
# 26398      Memphis Grizzlies  0022301193  2024-04-14  MEM vs. DEN  L  ...
# 26399      Charlotte Hornets  0022301187  2024-04-14    CHA @ CLE  W  ...
# 26400      Charlotte Hornets  0022301187  2024-04-14    CHA @ CLE  W  ...
#
#        REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  FANTASY_PTS  \
# 0        3    1    1    0    2   0    8          11         14.1
# 1        7    5    2    1    0   0   15           6         39.9
# 2       13   11    1    1    2   2   29          15         65.1
# 3       12    2    2    0    0   1   12          12         35.4
# 4        0    0    0    0    0   0    2           0          2.0
# ...    ...  ...  ...  ...  ...  ..  ...         ...          ...
# 26396    6    8    0    0    3   2    8          18         24.2
# 26397    3    7    0    0    3   5   15          -1         26.1
# 26398    2    0    0    0    0   0    0           0          2.4
# 26399    1    4    0    0    1   0    3          -8          9.2
# 26400    9    4    2    3    0   2   20          11         51.8
#
#        VIDEO_AVAILABLE
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 26396                1
# 26397                1
# 26398                1
# 26399                1
# 26400                1
#
# [26401 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26401 entries, 0 to 26400
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SEASON_ID          26401 non-null  str
#  1   PLAYER_ID          26401 non-null  int64
#  2   PLAYER_NAME        26401 non-null  str
#  3   TEAM_ID            26401 non-null  int64
#  4   TEAM_ABBREVIATION  26401 non-null  str
#  5   TEAM_NAME          26401 non-null  str
#  6   GAME_ID            26401 non-null  str
#  7   GAME_DATE          26401 non-null  str
#  8   MATCHUP            26401 non-null  str
#  9   WL                 26401 non-null  str
#  10  MIN                26401 non-null  int64
#  11  FGM                26401 non-null  int64
#  12  FGA                26401 non-null  int64
#  13  FG_PCT             24895 non-null  float64
#  14  FG3M               26401 non-null  int64
#  15  FG3A               26401 non-null  int64
#  16  FG3_PCT            20559 non-null  float64
#  17  FTM                26401 non-null  int64
#  18  FTA                26401 non-null  int64
#  19  FT_PCT             14232 non-null  float64
#  20  OREB               26401 non-null  int64
#  21  DREB               26401 non-null  int64
#  22  REB                26401 non-null  int64
#  23  AST                26401 non-null  int64
#  24  STL                26401 non-null  int64
#  25  BLK                26401 non-null  int64
#  26  TOV                26401 non-null  int64
#  27  PF                 26401 non-null  int64
#  28  PTS                26401 non-null  int64
#  29  PLUS_MINUS         26401 non-null  int64
#  30  FANTASY_PTS        26401 non-null  float64
#  31  VIDEO_AVAILABLE    26401 non-null  int64
# dtypes: float64(4), int64(20), str(8)
# memory usage: 6.4 MB

# %%
print(f"Number of games: {df['GAME_ID'].nunique()}")
print(f"Number of players: {df['PLAYER_ID'].nunique()}")
# Out:
# Number of games: 1230
# Number of players: 572

# %%
df.to_csv(
   "../data/NBA_PlayerGameLogs23_24.csv",
    index=False
)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\wood\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
import sklearn
import pandas
import numpy
import statsmodels
import nba_api

print("Everything imported successfully.")
# Out:
# Everything imported successfully.
